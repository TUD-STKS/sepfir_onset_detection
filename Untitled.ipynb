# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
best_pos_1 = [
    -3.14375358, -1.95505661, -1.15155036, -1.03053562,  0.31141095, -2.64935359,
    0.46992587, -2.39473662, 1.01101735, -1.05127331, -2.01896847, 0.08157085,
    -1.51120503, -1.43571744, 0.76432074, 0.4377325, -2.27676259, 2.54092305,
    1.57938124, -0.30064361, -2.0425695, 3.13436381, 13.28452697]

# %%
best_pos_2 = [
    -0.91423319, -0.23329208, -0.58494463, -0.50337153, -0.90865935, -0.21300875,
    -0.49215131, -1.45720377,  0.06840009, -0.26485775, -0.65617682, -2.07411694,
    2.3902488,  -3.36059287, -0.504755,   -0.86338304,  3.74242125, -1.87637446,
    1.30886338,  0.6502578,   3.4950233,  -1.9002161,  13.65007485]

# %%
fig, axs = plt.subplots()

sns.pointplot(x=np.arange(11), y=best_pos_1[:11], label="Best pos 1", color=sns.color_palette()[0], ax=axs)
sns.pointplot(x=np.arange(11), y=best_pos_2[:11], label="Best pos 2", color=sns.color_palette()[1], ax=axs)
plt.tight_layout()
plt.legend()

# %%
fig, axs = plt.subplots()

sns.pointplot(x=np.arange(11), y=best_pos_1[11:-1], label="Best pos 1", color=sns.color_palette()[0], ax=axs)
sns.pointplot(x=np.arange(11), y=best_pos_2[11:-1], label="Best pos 2", color=sns.color_palette()[1], ax=axs)
plt.tight_layout()
plt.legend()

# %%
import random

# %%
random.seed(42)

# %%
random.randint(1, 10)
# Out:
# 2

# %%
random.randint(1, 10)
# Out:
# 1

# %%
random.randint(1, 10)
# Out:
# 5

# %%
random.randint(1, 10)
# Out:
# 4

# %%
random.randint(1, 10)
# Out:
# 4

# %%
random.randint(1, 10)
# Out:
# 3

# %%
random.randint(1, 10)
# Out:
# 2

# %%
random.randint(1, 10)
# Out:
# 9

# %%
np.random.uniform(0, 20, 23)
# Out:
# array([ 4.65485143, 10.61500636, 14.93421505, 16.33632417,  1.20108969,
#         5.20591929, 18.73587675, 18.82065202,  0.21403921, 12.1081034 ,
#        14.40342142, 16.26207038,  2.90741103,  3.77961983, 13.9860269 ,
#        14.9909211 ,  0.38585808,  4.83685668,  0.3263753 ,  1.79998861,
#         5.53075933, 13.3281141 , 14.24615741])

# %%
rng = np.random.default_rng(42)
rng.uniform(-20, 20, 5)
# Out:
# array([ 10.95824194,  -2.44486241,  14.3439168 ,   7.89472116,
#        -16.23290608])

# %%
rng = np.random.default_rng(42)
particles = []
num_particles = 50
freq_filter_length = 3
time_filter_length = 3
rand_min = -10
rand_max = 10

for i in range(num_particles):
    arr = rng.uniform(rand_min, rand_max, freq_filter_length + time_filter_length)
    particle = np.append(arr, rng.uniform(0,20)).tolist()
    particles.append(particle)

init_pos = np.array(particles, dtype='float64')
init_pos
# Out:
# array([[ 5.47912097, -1.2224312 ,  7.1719584 ,  3.94736058, -8.11645304,
#          9.51244703, 15.22279404],
#        [ 5.72128611, -7.43772735, -0.99228124, -2.58403952,  8.53529978,
#          2.8773024 , 16.45523227],
#        [-1.13171602, -5.45522556,  1.09169574, -8.72365488,  6.55262344,
#          2.63328798, 15.1617548 ],
#        [-2.90948064,  9.41396049,  7.86242243,  5.56766994, -6.10722584,
#         -0.66557993,  0.87607532],
#        [-6.91421016,  3.66097906,  4.89524312,  9.35019465, -3.48349284,
#         -2.59080588,  9.39111623],
#        [-6.21057282, -7.40156989, -0.48590148, -5.46181302,  3.39627989,
#         -1.25696162, 16.65356392],
#        [ 4.00530204, -3.75266717,  6.64519603,  6.09528715, -2.25043242,
#         -4.23343792, 13.64991008],
#        [-7.20495033, -6.00183595, -9.8527546 ,  5.73848755,  3.29701713,
#          4.10330757, 15.61458062],
#        [-0.82168449,  1.37482392, -7.20406004, -7.70939853,  3.36805924,
# ...
